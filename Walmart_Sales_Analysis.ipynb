# %% [markdown]
# # Jar Business Analyst Intern Assignment

# %% [markdown]
# ### 1) Walmart Sales Analysis

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#Importing dataset
walmart = pd.read_excel("C:/Users/user/Downloads/Walmart Sales.xlsx")
walmart
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      A  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      B     Yangon        Member    Male
# 4    373-73-7910      C     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      A  Naypyitaw        Normal    Male
# 996  303-96-2227      A   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      B     Yangon        Normal    Male
# 999  849-09-3807      C     Yangon        Member  Female
#
#                Product line  Unit price  Quantity       Date      Time  \
# 0         Health and beauty       74.69         7   1/5/2019  13:08:00
# 1    Electronic accessories       15.28         5   3/8/2019  10:29:00
# ...

# %%
#Creating a copy of the dataset
walmart_copy = walmart.copy()
walmart_copy
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      A  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      B     Yangon        Member    Male
# 4    373-73-7910      C     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      A  Naypyitaw        Normal    Male
# 996  303-96-2227      A   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      B     Yangon        Normal    Male
# 999  849-09-3807      C     Yangon        Member  Female
#
#                Product line  Unit price  Quantity       Date      Time  \
# 0         Health and beauty       74.69         7   1/5/2019  13:08:00
# 1    Electronic accessories       15.28         5   3/8/2019  10:29:00
# ...

# %%
walmart_copy.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      A  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      B     Yangon        Member    Male
# 4  373-73-7910      C     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity       Date      Time  \
# 0       Health and beauty       74.69         7   1/5/2019  13:08:00
# 1  Electronic accessories       15.28         5   3/8/2019  10:29:00
# 2      Home and lifestyle       46.33         7   3/3/2019  13:23:00
# 3       Health and beauty       58.22         8  1/27/2019  20:33:00
# 4       Sports and travel       86.31         7   2/8/2019  10:37:00
#
#        Payment  Rating
# 0      Ewallet     9.1
# 1         Cash     9.6
# 2  Credit card     7.4
# 3      Ewallet     8.4
# 4      Ewallet     5.3

# %%
walmart_copy.tail(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      A  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      A   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      B     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      C     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity       Date      Time  Payment  Rating
# 995       40.35         1  1/29/2019  13:46:00  Ewallet     6.2
# 996       97.38        10   3/2/2019  17:16:00  Ewallet     4.4
# 997       31.84         1   2/9/2019  13:22:00     Cash     7.7
# 998       65.82         1  2/22/2019  15:33:00     Cash     4.1
# 999       88.34         7  2/18/2019  13:28:00     Cash     6.6

# %%
#Checking for dataset info
walmart_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Invoice ID     1000 non-null   object
#  1   Branch         1000 non-null   object
#  2   City           1000 non-null   object
#  3   Customer type  1000 non-null   object
#  4   Gender         1000 non-null   object
#  5   Product line   1000 non-null   object
#  6   Unit price     1000 non-null   float64
#  7   Quantity       1000 non-null   int64
#  8   Date           1000 non-null   object
#  9   Time           1000 non-null   object
#  10  Payment        1000 non-null   object
#  11  Rating         1000 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 93.9+ KB

# %%
#Splitting the date column into day,month and year
walmart_copy['Month'] = walmart_copy['Date'].str.split('/',expand = True)[0]
walmart_copy['Day'] = walmart_copy['Date'].str.split('/',expand = True)[1]
walmart_copy['Year'] = walmart_copy['Date'].str.split('/',expand = True)[2]

# %%
#Dropping the 'Date' Column
walmart_copy.drop(['Date'],axis=1,inplace=True)

# %%
#Checking the number of unique values of each column
walmart_copy.nunique()
# Out:
# Invoice ID       1000
# Branch              3
# City                3
# Customer type       2
# Gender              2
# Product line        6
# Unit price        943
# Quantity           10
# Time              506
# Payment             3
# Rating             61
# Month               3
# Day                31
# Year                1
# dtype: int64

# %%
#Dropping the 'Invoice ID' column, as there are many unique values in that column.
walmart_copy.drop(['Invoice ID'],axis=1,inplace=True)

# %% [markdown]
# A. Analyze the performance of sales and revenue at the city and branch level.
#
# B. What is the average price of an item sold at each branch of the city.
#
# C. Analyze the performance of sales and revenue, Month over Month across the Product line, Gender, and Payment Method, and identify the focus areas to get better sales for April 2019.

# %%
# A. Analysing performance of sales and revenue at the city and branch level
# First, we create a new column 'Revenue' (Revenue = P * Q) so that it will easy for our further analysis
walmart_copy['Revenue'] = walmart_copy['Unit price'] * walmart_copy['Quantity']

# %%
walmart_copy.head()
# Out:
#   Branch       City Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      A  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      B     Yangon        Member    Male       Health and beauty       58.22
# 4      C     Yangon        Normal    Male       Sports and travel       86.31
#
#    Quantity      Time      Payment  Rating Month Day  Year  Revenue
# 0         7  13:08:00      Ewallet     9.1     1   5  2019   522.83
# 1         5  10:29:00         Cash     9.6     3   8  2019    76.40
# 2         7  13:23:00  Credit card     7.4     3   3  2019   324.31
# 3         8  20:33:00      Ewallet     8.4     1  27  2019   465.76
# 4         7  10:37:00      Ewallet     5.3     2   8  2019   604.17

# %%
#Analysing performance of sales and revenue at city level
a = sns.barplot(x = 'City',y = 'Quantity',data = walmart_copy,estimator = 'sum',errorbar = None)
a.bar_label(a.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '1859'), Text(0, 0, '1831'), Text(0, 0, '1820')]

# %% [markdown]
# The city 'Yangon' has the highest sum of sales amongst the three cities in observation for our analysis, followed by the cities 'Naypyitaw' and 'Mandalay' respectively.

# %%
b = sns.barplot(x = 'City',y = 'Revenue',data = walmart_copy,estimator = 'sum',errorbar = None)
b.bar_label(b.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '101143'), Text(0, 0, '105304'), Text(0, 0, '101141')]

# %% [markdown]
# In the contrary, the city 'Naypyitaw' has the highest total revenue amongst the three cities in observation, followed by 'Yangon' and 'Mandalay' respectively.
#
# Even though the total sum of sales is high in the city 'Yangon', the total revenue is quite low compared to the city 'Naypyitaw' because the unit price sold at 'Yangon' is quite less compared to 'Naypyitaw' (in my opinion).

# %%
#Analysing performance of sales and revenue at branch level
c = sns.barplot(x = 'Branch',y = 'Quantity',data = walmart_copy,estimator = 'sum',errorbar = None)
c.bar_label(c.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '1883'), Text(0, 0, '1899'), Text(0, 0, '1728')]

# %%
d = sns.barplot(x = 'Branch',y = 'Revenue',data = walmart_copy,estimator = 'sum',errorbar = None)
d.bar_label(d.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '103763'), Text(0, 0, '107567'), Text(0, 0, '96257.2')]

# %% [markdown]
# The Branch 'B' has the highest sum of sales and revenue amongst the three branches.

# %%
# B. What is the average price of an item sold at each branch of the city.
#Extracting data from each city
#Yangon
a1 = walmart_copy[walmart_copy['City'] == 'Yangon']
a1
# Out:
#     Branch    City Customer type  Gender            Product line  Unit price  \
# 0        A  Yangon        Member  Female       Health and beauty       74.69
# 2        A  Yangon        Normal    Male      Home and lifestyle       46.33
# 3        B  Yangon        Member    Male       Health and beauty       58.22
# 4        C  Yangon        Normal    Male       Sports and travel       86.31
# 6        A  Yangon        Member  Female  Electronic accessories       68.84
# ..     ...     ...           ...     ...                     ...         ...
# 990      B  Yangon        Normal  Female      Food and beverages       56.56
# 992      C  Yangon        Normal    Male  Electronic accessories       58.03
# 997      A  Yangon        Member    Male      Food and beverages       31.84
# 998      B  Yangon        Normal    Male      Home and lifestyle       65.82
# 999      C  Yangon        Member  Female     Fashion accessories       88.34
#
# ...

# %%
e = sns.barplot(x = 'Branch',y = 'Unit price',data = a1,errorbar = None)
e.bar_label(e.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '55.6393'), Text(0, 0, '56.0111'), Text(0, 0, '52.6846')]

# %% [markdown]
# The average price of an item sold in the city 'Yangon' at each branch is as follows:
#
# Branch A = 55.63
#
# Branch B = 56.01
#
# Branch C = 52.68
#
# (Do not have much info about the currency whether if it's in USD or Myanmar Kyat)

# %%
#Naypyitaw
b1 = walmart_copy[walmart_copy['City'] == 'Naypyitaw']
b1
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 1        A  Naypyitaw        Normal  Female  Electronic accessories
# 5        B  Naypyitaw        Normal    Male  Electronic accessories
# 7        C  Naypyitaw        Normal  Female      Home and lifestyle
# 20       A  Naypyitaw        Member    Male  Electronic accessories
# 34       B  Naypyitaw        Member  Female      Food and beverages
# ..     ...        ...           ...     ...                     ...
# 983      C  Naypyitaw        Normal    Male       Health and beauty
# 984      A  Naypyitaw        Normal    Male  Electronic accessories
# 988      B  Naypyitaw        Member    Male  Electronic accessories
# 994      C  Naypyitaw        Member  Female  Electronic accessories
# 995      A  Naypyitaw        Normal    Male       Health and beauty
#
#      Unit price  Quantity      Time  Payment  Rating Month Day  Year  Revenue
# ...

# %%
f = sns.barplot(x = 'Branch',y = 'Unit price',data = b1,errorbar = None)
f.bar_label(f.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '54.1232'), Text(0, 0, '57.7857'), Text(0, 0, '57.941')]

# %% [markdown]
# The average price of an item sold in the city 'Naypyitaw' at each branch is as follows:
#
# Branch A = 54.12
#
# Branch B = 57.78
#
# Branch C = 57.94
#
# (Do not have much info about the currency whether if it's in USD or Myanmar Kyat)

# %%
#Mandalay
c1 = walmart_copy[walmart_copy['City'] == 'Mandalay']
c1
# Out:
#     Branch      City Customer type  Gender            Product line  \
# 9        A  Mandalay        Member  Female      Food and beverages
# 10       B  Mandalay        Member  Female     Fashion accessories
# 11       C  Mandalay        Member    Male  Electronic accessories
# 15       A  Mandalay        Member  Female       Sports and travel
# 19       B  Mandalay        Normal  Female      Home and lifestyle
# ..     ...       ...           ...     ...                     ...
# 987      C  Mandalay        Member    Male       Health and beauty
# 989      A  Mandalay        Member    Male       Health and beauty
# 991      B  Mandalay        Normal  Female       Sports and travel
# 993      C  Mandalay        Normal    Male     Fashion accessories
# 996      A  Mandalay        Normal  Female      Home and lifestyle
#
#      Unit price  Quantity      Time      Payment  Rating Month Day  Year  \
# 9         54.84         3  13:27:00  Credit card     5.9     2  20  2019
# ...

# %%
g = sns.barplot(x = 'Branch',y = 'Unit price',data = c1,errorbar = None)
g.bar_label(g.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '53.3539'), Text(0, 0, '56.1333'), Text(0, 0, '57.9583')]

# %% [markdown]
# The average price of an item sold in the city 'Mandalay' at each branch is as follows:
#
# Branch A = 53.35
#
# Branch B = 56.13
#
# Branch C = 57.95
#
# (Do not have much info about the currency whether if it's in USD or Myanmar Kyat)

# %%
#C. Analyze the performance of sales and revenue, Month over Month across the Product line, Gender and Payment Method and identify the focus areas to get better sales for April 2019.

#Analysing performance of sales and revenue during the month of January.

#Jan
d1 = walmart_copy[walmart_copy['Month'] == '1']
d1
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 3        B     Yangon        Member    Male       Health and beauty
# 8        B     Yangon        Member  Female       Health and beauty
# 15       A   Mandalay        Member  Female       Sports and travel
# 17       A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 984      A  Naypyitaw        Normal    Male  Electronic accessories
# 987      C   Mandalay        Member    Male       Health and beauty
# 989      A   Mandalay        Member    Male       Health and beauty
# 991      B   Mandalay        Normal  Female       Sports and travel
# 995      A  Naypyitaw        Normal    Male       Health and beauty
#
#      Unit price  Quantity      Time      Payment  Rating Month Day  Year  \
# 0         74.69         7  13:08:00      Ewallet     9.1     1   5  2019
# ...

# %%
#Analysing performance of sales and revenue at each Product Line during January
plt.figure(figsize=(12,10))
h = sns.barplot(x = 'Product line',y = 'Quantity',data = d1,estimator = 'sum',errorbar = None)
h.bar_label(h.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '254'),
#  Text(0, 0, '375'),
#  Text(0, 0, '325'),
#  Text(0, 0, '333'),
#  Text(0, 0, '342'),
#  Text(0, 0, '336')]

# %%
plt.figure(figsize=(12,10))
h = sns.barplot(x = 'Product line',y = 'Revenue',data = d1,estimator = 'sum',errorbar = None)
h.bar_label(h.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '15603'),
#  Text(0, 0, '20635.3'),
#  Text(0, 0, '18638.6'),
#  Text(0, 0, '17934.6'),
#  Text(0, 0, '19518.8'),
#  Text(0, 0, '18423.9')]

# %%
#Analysing performance of sales and revenue of each Gender during month of January
h = sns.barplot(x = 'Gender',y = 'Quantity',data = d1,estimator = 'sum',errorbar = None)
h.bar_label(h.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '1019'), Text(0, 0, '946')]

# %%
h = sns.barplot(x = 'Gender',y = 'Revenue',data = d1,estimator = 'sum',errorbar = None)
h.bar_label(h.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '56322.8'), Text(0, 0, '54431.3')]

# %%
#Analysing performance of sales and revenue based of payment mode during month of January
h = sns.barplot(x = 'Payment',y = 'Quantity',data = d1,estimator = 'sum',errorbar = None)
h.bar_label(h.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '635'), Text(0, 0, '622'), Text(0, 0, '708')]

# %%
h = sns.barplot(x = 'Payment',y = 'Revenue',data = d1,estimator = 'sum',errorbar = None)
h.bar_label(h.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '34547.8'), Text(0, 0, '36425.3'), Text(0, 0, '39781')]

# %%
#Analysing performance of sales and revenue during the month of February.

#Feb
e1 = walmart_copy[walmart_copy['Month'] == '2']
e1
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 4        C     Yangon        Normal    Male       Sports and travel
# 6        A     Yangon        Member  Female  Electronic accessories
# 7        C  Naypyitaw        Normal  Female      Home and lifestyle
# 9        A   Mandalay        Member  Female      Food and beverages
# 10       B   Mandalay        Member  Female     Fashion accessories
# ..     ...        ...           ...     ...                     ...
# 993      C   Mandalay        Normal    Male     Fashion accessories
# 994      C  Naypyitaw        Member  Female  Electronic accessories
# 997      A     Yangon        Member    Male      Food and beverages
# 998      B     Yangon        Normal    Male      Home and lifestyle
# 999      C     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity      Time      Payment  Rating Month Day  Year  \
# 4         86.31         7  10:37:00      Ewallet     5.3     2   8  2019
# ...

# %%
#Analysing performance of sales and revenue at each Product Line during February
plt.figure(figsize=(12,10))
i = sns.barplot(x = 'Product line',y = 'Quantity',data = e1,estimator = 'sum',errorbar = None)
i.bar_label(i.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '226'),
#  Text(0, 0, '313'),
#  Text(0, 0, '205'),
#  Text(0, 0, '349'),
#  Text(0, 0, '295'),
#  Text(0, 0, '266')]

# %%
plt.figure(figsize=(12,10))
i = sns.barplot(x = 'Product line',y = 'Revenue',data = e1,estimator = 'sum',errorbar = None)
i.bar_label(i.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '13152'),
#  Text(0, 0, '16536.1'),
#  Text(0, 0, '11842.3'),
#  Text(0, 0, '19048'),
#  Text(0, 0, '18104.6'),
#  Text(0, 0, '13906.9')]

# %%
#Analysing performance of sales and revenue of each Gender during month of February
i = sns.barplot(x = 'Gender',y = 'Quantity',data = e1,estimator = 'sum',errorbar = None)
i.bar_label(i.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '703'), Text(0, 0, '951')]

# %%
i = sns.barplot(x = 'Gender',y = 'Revenue',data = e1,estimator = 'sum',errorbar = None)
i.bar_label(i.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '38937'), Text(0, 0, '53652.9')]

# %%
#Analysing performance of sales and revenue based of payment mode during month of February
i = sns.barplot(x = 'Payment',y = 'Quantity',data = e1,estimator = 'sum',errorbar = None)
i.bar_label(i.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '553'), Text(0, 0, '505'), Text(0, 0, '596')]

# %%
i = sns.barplot(x = 'Payment',y = 'Revenue',data = e1,estimator = 'sum',errorbar = None)
i.bar_label(i.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '28679.1'), Text(0, 0, '29866.7'), Text(0, 0, '34044.1')]

# %%
#Analysing performance of sales and revenue during the month of March.

#March
f1 = walmart_copy[walmart_copy['Month'] == '3']
f1
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 1        A  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 5        B  Naypyitaw        Normal    Male  Electronic accessories
# 11       C   Mandalay        Member    Male  Electronic accessories
# 14       B     Yangon        Normal  Female       Health and beauty
# ..     ...        ...           ...     ...                     ...
# 982      A     Yangon        Member  Female       Sports and travel
# 988      B  Naypyitaw        Member    Male  Electronic accessories
# 990      B     Yangon        Normal  Female      Food and beverages
# 992      C     Yangon        Normal    Male  Electronic accessories
# 996      A   Mandalay        Normal  Female      Home and lifestyle
#
#      Unit price  Quantity      Time      Payment  Rating Month Day  Year  \
# 1         15.28         5  10:29:00         Cash     9.6     3   8  2019
# ...

# %%
#Analysing performance of sales and revenue at each Product Line during March
plt.figure(figsize=(12,10))
j = sns.barplot(x = 'Product line',y = 'Quantity',data = f1,estimator = 'sum',errorbar = None)
j.bar_label(j.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '325'),
#  Text(0, 0, '364'),
#  Text(0, 0, '334'),
#  Text(0, 0, '319'),
#  Text(0, 0, '271'),
#  Text(0, 0, '278')]

# %%
plt.figure(figsize=(12,10))
j = sns.barplot(x = 'Product line',y = 'Revenue',data = f1,estimator = 'sum',errorbar = None)
j.bar_label(j.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '17279.4'),
#  Text(0, 0, '19936'),
#  Text(0, 0, '17341.2'),
#  Text(0, 0, '18710.7'),
#  Text(0, 0, '15191.4'),
#  Text(0, 0, '15784.7')]

# %%
#Analysing performance of sales and revenue of each Gender during month of March
j = sns.barplot(x = 'Gender',y = 'Quantity',data = f1,estimator = 'sum',errorbar = None)
j.bar_label(j.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '899'), Text(0, 0, '992')]

# %%
j = sns.barplot(x = 'Gender',y = 'Revenue',data = f1,estimator = 'sum',errorbar = None)
j.bar_label(j.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '49912.8'), Text(0, 0, '54330.6')]

# %%
#Analysing performance of sales and revenue based of payment mode during month of March
j = sns.barplot(x = 'Payment',y = 'Quantity',data = f1,estimator = 'sum',errorbar = None)
j.bar_label(j.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '592'), Text(0, 0, '595'), Text(0, 0, '704')]

# %%
j = sns.barplot(x = 'Payment',y = 'Revenue',data = f1,estimator = 'sum',errorbar = None)
j.bar_label(j.containers[0], fontsize=10)
# Out:
# [Text(0, 0, '33038.2'), Text(0, 0, '29676.6'), Text(0, 0, '41528.5')]

# %% [markdown]
# Conclusion:
#
# Things to focus on to get better sales in the month of April 2019:
#
# 1.) As April is the hottest month of the season, we can focus on improving production of Food and Beverages by introducing new line of beverages. And Also improving production in the line of Home and Lifestyle, as customers tend to buy Air Conditioners, Fans etc. (General Point of View)
#
# 2.) We need to analyse a certain pattern for the first 5-10 days of the month, if there is a pattern in increased female customers, we focus on improving sales in the product lines such as Food and Beverages, Health and Beauty, Fashion Accessories. And if there is a pattern in increased male customers, we focus on improving sales in the product lines such as Electronic Accessories, Home and Lifestyle. (As these were the trends noticed in last three months)
#
# 3.) As noticed from the above months, in order to maximise sales we need to focus on cash-only payments.
#
# How? -
# a) By Offering discounts for Cash Payments
#
# b) Creating Bundle Deals - Create bundle deals where customers can purchase multiple items together at a discounted price when paying with cash.
#
# c) Display Pricing in Cash - Display cash amounts rather than credit card amounts to make cash payments seem more appealing.
#
# d) Limited Time Offers - Promote limited time offers exclusively for cash paying customers.
